# %%
# %matplotlib notebook 
from obspy.clients.fdsn import Client
from obspy import UTCDateTime

# %%
client = Client('http://165.98.224.52:8081/')
starttime = UTCDateTime()-60*60*24*360
endtime = UTCDateTime()
inventory = client.get_stations(network="*", station="*",
                                    starttime=starttime,
                                    endtime=endtime, 
                                    lat=11.984562,
                                    lon=-86.168006,
                                    minradius=0.0,
                                    maxradius=0.1,
                                    level="CHAN")
inventory.write("sc-local-proc_fdsnws_station_masaya_1year.kml", format="KML")
inventory.plot(color_per_network=True,projection="local")
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %%
inventory = client.get_stations(network="*", station="*",
                                    starttime=starttime,
                                    endtime=endtime, 
                                    lat=12.424230,
                                    lon=-86.538392,
                                    minradius=0.0,
                                    maxradius=0.15,
                                    level="CHAN")
inventory.write("sc-local-proc_fdsnws_station_momotombo_1year.kml", format="KML")
inventory.plot(color_per_network=True,projection="local")
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %%
client = Client('http://165.98.224.52:8081/')
starttime = UTCDateTime()-60*60*24*360
endtime = UTCDateTime()
inventory = client.get_stations(network="*", station="*",
                                    starttime=starttime,
                                    endtime=endtime, level="CHAN")

# %%
inventory.write("sc-local-proc_fdsnws_station_1year.kml", format="KML")

# %%
inventory.plot(projection="local", color_per_network=True)
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %%
client = Client('http://service.scedc.caltech.edu')
starttime = UTCDateTime()-60*60*24*30
endtime = UTCDateTime()+60*60*24*30
inventory = client.get_stations(network="*", station="*",
                                    starttime=starttime,
                                    endtime=endtime,
                                    level="station")#, 
#                                    lat=34.071,
#                                    lon=-117.773,
#                                    minradius=0.0,
#                                    maxradius=5.293)

# %%
inventory.write("caltech_fdsnws_station_around_LA_1year.kml", format="KML")

# %%
inventory.plot(color_per_network=True)#,projection="local")  
inventory.write('test.xml',format='sc3ml')
# Out:
# <div id='9fc03d23-bc40-4d62-948f-398a7b1b9805'></div>
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/imaging/maps.py:402: MatplotlibDeprecationWarning: The set_axis_bgcolor function was deprecated in version 2.0. Use set_facecolor instead.
#   ax.set_axis_bgcolor(water_fill_color)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3236: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3245: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
# Inventory created at 2017-03-03T13:51:06.000000Z
# 	Created by: SCEDC WEB SERVICE: fdsnws-station | version: 1.1
# 		    http://service.scedc.caltech.edu/fdsnws/station/1/query?net=*&sta=*...
# 	Sending institution: SCEDC (SCEDC)
# ...

# %%
from obspy.core import UTCDateTime
from obspy.fdsn.client import Client  #obspy 0.10 obspy.fdsn.client / last obspy.clients.fdsn
n=0
while n<100:
    n+=1
    client = Client('IRIS')
    t = UTCDateTime(2009,1,1,10)
    inv = client.get_stations(network = 'TA',station = 'E24A',starttime = t,endtime =t+400)
    #print(inv)
